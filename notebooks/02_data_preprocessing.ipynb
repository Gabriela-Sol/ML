# %%
# Importar librerías
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer

# Cargar datos
df = pd.read_csv('../datasets/healthcare-dataset-stroke-data.csv')

# %%
# Manejar valores faltantes
# Para columnas numéricas: imputar con la media
numeric_columns = df.select_dtypes(include=[np.number]).columns
imputer_numeric = SimpleImputer(strategy='mean')
df[numeric_columns] = imputer_numeric.fit_transform(df[numeric_columns])

# Para columnas categóricas: imputar con el más frecuente
categorical_columns = df.select_dtypes(include=['object']).columns
imputer_categorical = SimpleImputer(strategy='most_frequent')
df[categorical_columns] = imputer_categorical.fit_transform(df[categorical_columns])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Manejar valores faltantes
#       2 # Para columnas numéricas: imputar con la media
# ----> 3 numeric_columns = df.select_dtypes(include=[np.number]).columns
#       4 imputer_numeric = SimpleImputer(strategy='mean')
#       5 df[numeric_columns] = imputer_numeric.fit_transform(df[numeric_columns])
#
# NameError: name 'np' is not defined

# %%
# Codificar variables categóricas
label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
# Normalizar características numéricas
scaler = StandardScaler()
df[numeric_columns] = scaler.fit_transform(df[numeric_columns])

# %%
# Guardar el dataset preprocesado
df.to_csv('../datasets/dataset_preprocesado.csv', index=False)
print("Dataset preprocesado guardado.")
